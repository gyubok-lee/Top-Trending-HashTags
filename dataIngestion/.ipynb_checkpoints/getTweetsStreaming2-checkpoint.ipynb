# %%
# Twitter Streaming API
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream, StreamListener

# API Key & Token Info
import const

# Kafka
from kafka import KafkaProducer
from kafka import KafkaConsumer
from kafka.errors import KafkaError

import json

# %%
class Producer():
    def __init__(self, bootstrap_servers):
        try:
            self.producer = KafkaProducer(bootstrap_servers=bootstrap_servers,
                                          max_block_ms = 10000,
                                          retries = 0, 
                                          acks = 1, 
                                          value_serializer = lambda v: json.dumps(v).encode("utf-8"))
        except KafkaError as exc:
            print(f"kafka producer - Exception during connecting to broker - {exc}")
            return False
    
    def stop(self):
        self.producer.close()

    def send_data(self, topic, data):        
        # Asynchronous by default
        self.producer.send(topic, data).add_callback(self.on_send_success).add_errback(self.on_send_error)
        
        # block until all async messages are sent
        self.producer.flush()
    
    def on_send_success(self, record_metadata):
        print("**********Send Success***********")
        print("record_metadata.topic: ", record_metadata.topic)
        print("record_metadata.partition: ", record_metadata.partition)
        print("record_metadata.offset: ", record_metadata.offset)
        pass

    def on_send_error(self, excp):
        print("**********Send Error Occur**********")
        log.error("I am an errback", exc_info=excp)

# %%
# Read the credentials form const
CONSUMER_KEY = const.CONSUMER_KEY
CONSUMER_SECRET = const.CONSUMER_SECRET
ACCESS_TOKEN = const.ACCESS_TOKEN
ACCESS_SECRET = const.ACCESS_SECRET

# %%
class TweetsListener(StreamListener):
    def __init__(self):
        super(TweetsListener, self).__init__()
        self.producer = kafka_producer
        self.topic_name = topic_name
        
    def on_data(self, data):
        try:
            msg = json.loads(data)
            
            if not msg['truncated']:
                text = msg['text']
            else:
                text = msg['extended_tweet']['full_text']

            print(text)
            
            #text = text.encode('utf-8')
            self.producer.send_data(self.topic_name, text)

        except BaseException as e:
            print(f"error: {str(e)}")

        return True
    
    def on_error(self, status):
        print(status)
        
        return True

# %%
# Create Kafka Producer 
bootstrap_servers = ['localhost:9092'] # kafka broker ip
topic_name = 'tweets' # kafka topic name
kafka_producer = Producer(bootstrap_servers=bootstrap_servers)

 #Create Auth object
auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# %%
# Send tweets to Kafka Broker
twitter_stream = Stream(auth, listener=TweetsListener())

twitter_stream.sample(languages =["en"])
# Out:
# So cute! ! ! One family dressed their children as mini Taylor on Halloween. https://t.co/bbon1M0y99
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45566
# RT @chulipsjj: he's about to throw his paws #ENHYPEN_JAY https://t.co/4t4hExSIHc
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45567
# RT @BuffaloBills: Peyton Manning's son has "J. Allen" on the back of his flag football jersey. 🤣
#
# 📺: @espn https://t.co/d7RJhvWun1
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45568
# The immature preaching about maturity 🤣🤦🏻‍♂️
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45569
# RT @glofilez: niggas get clowned for anything https://t.co/z57eCiClXx
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45570
# RT @BigTroyHuncho: I couldn’t let another mf take my happiness away. Ion see how y’all let that happen. Gotta see shit for what it is
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45571
# Kids are so scary to me idk
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45572
# @brettsey5 That’s exciting news for him
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45573
# new layout! also updated my carrd🩰 https://t.co/ZfbytCeaNN
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45574
# RT @JKSTlGMA: nove
# I vote for #BUTTER as #TheMusicVideo of 2021 at the #PCAs (@BTS_twt)
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45779
# @Jk16010 @NoWhiteGuiltNWG its like for years white women were ok with things, UNTIL they become the target also,ALL whites are the target terry the moron needs to get it https://t.co/NrmcPcocBn
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45780
# @dokaseason which one haven’t you heard yet?
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45781
# ...
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46403
# my birthday is fast approaching baka naman 🥺
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46404
# Good morning ...... https://t.co/tE8yJzkwAa
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46405
# RT @choi_bts2: I'm voting 🗳 for #BTS for #TheGroup of 2021 #PCAs @BTS_twt
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46406
# @TRescuedog You are adorable 🥰🥰🥰🥰
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46407
# RT @KleitoNft: $15 in 120 mins🎁
#
# -rt &amp; follow @iTrading_Bot + RT their📍
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46408
# —We’ll go now.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46409
# RT @taekookiessyy: I vote BTS’ #BUTTER as #TheSong of 2021 at #PCAs
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46410
# RT @BINI_SVTeam: [Spotify Streams Update]
#
# Golden Arrow - 120,643
# Born To Win - 661,645
# Na Na Na - 53,127
# Kapit Lang - 159,470
# Kinikilig -…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46411
# @cinderella19114 @Dawar_Tweets Happiest birthday bruhhh 🎊
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46412
# @Elarunal She looks like a person I'd like to know. Love her face, you did an amazing job with her.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46413
# RT @Jixe: $150 ~ 2 hours
#
# - retweet (🔔)
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46414
# Hawks don’t lose!
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46415
# @Vidyut2222 @ShefVaidya Shiva Trilogy??
# It is fiction and has to do nothing with our tradition and culture.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46416
# RT @OregonZoo: Happy Halloween https://t.co/8JbpSfANBM
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46417
# 🤣😂🤣😂😂😂😂 Cute
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46418
# I vote #BTS for #TheGroup of 2021 #PCAs @BTS_twt!!
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46419
# RT @MelakuZion: happy halloween🐍🐍 @youngthug https://t.co/izRkAR9bOf
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46420
# RT @luthorsrojas: Nah I will complain bc they decided to make Andrea horrible this season only to prop him up and it’s gross writing
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46421
# RT @bbwspice: they’re heavy 🤲🥺 https://t.co/SJXXSkZfeP
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46422
# @geoffschwartz Just a weird ass season. Hope to get away with a dub if not packers raiders n cowboys are not easy. Can be 3-7 real quick, at that point what ya do?
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46423
# @dinkerfn i dont have school tmrw
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46424
# RT @ElectionWiz: Two things for tomorrow:
#
# 1) Youngkin cannot get blown out in Loudoun and Fairfax counties.
#
# 2) Youngkin needs a healthy t…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46425
# I use LunarCrush to track social insights for cryptocurrencies. Check it out!
#
# https://t.co/JkgJLq8C8B
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46426
# YooShi 1-week social activity:
#
# Galaxy Score™ 58 out of 100
# AltRank™ 6 out of 3252
# 92,187 social mentions
# 130,191,139 social engagements
# 336 social contributors
# 0.60% social dominance
# 7,400 shared links
#
# https://t.co/FAYtjtPxI5
# $yooshi #yooshi #LunarShare
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46427
# 9⃣ #SuperJuniorDnE_Countdown  ⌛️ #ZERO
# "Good morning🌤 Ah, it's still 9am in the morning? Ah! How are we supposed to wait for 6pm?
# (Only good people can see the *imaginary* watch)
# Have a nice day today!!"
# #은혁 #EUNHYUK #동해 #DONGHAE #SUPERJUNIOR
#
# https://t.co/sM3Ise7B5m
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46428
# CR WLW WEEK: COSTUMES
# (Scorpion x Bellflower)
# when red riding hood got lost in the forest, she found that the big bad wolf wasn’t so bad after all!
# #crwlw_week #cookierun #cookierunfanart #scorpibell https://t.co/6JD4St2okU
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46429
# i cant hadle this confusion
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46430
# RT @_krystelaa: y’all smell that? Smells like christmas to me
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46431
# RT @CryptoVonDoom: 🚨FRENS - You can win #NFTs from Rug Pull Frens &amp; Wasteland Union!
#
# To Enter:
# 1️⃣ RT /❤️/ Tag Freaks &amp; Frens
# 2️⃣ Follow:…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46432
# RT @horse_feedbag: Michael man look I’m sorry I didn’t tell you where I got the corn dog can we heal this divide https://t.co/d5qnQJpQMB
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46433
# @veee_singularyy morning, u too
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46434
# Chiefs window closing?
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46435
# RT @junhuihuihuis: why not @pledis_17 https://t.co/t5rcxUJntF
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46436
# RT @SafeCap_Token: 💵SafeCap New Airdrop is live !!!
#
# 🏮Welcome to SafeCap official Global Community
#
# Participate in our Airdrop and earn to…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46437
# @wadelowery17 judging from past behavior, the American People had no problem with vaccine mandates in the recent past. youre right it is a free country, just like you are free to home school your kid if you choose to not to vaccinate your kid with those 8 required vaccines
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46438
# RT @TaliaLuvsButts: thirsty king is thirsty~
#
# A patron made a special request of some Theseus X Asterius' Dick sketches and I was too slutt…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46439
# RT @J_Mei21: retweet if you hate matt gaetz!
#
# https://t.co/jR7y07d85Z
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46440
# RT @97JJHOLIC: [Exclusive] NCT's Jaehyun, 'Bungee Jumping' OTT remake starring... Acting as Yeo Hyeon-soo! ACTOR JAEHYUN IS BACK 😭😭😭😭 WHO E…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46441
# @TheGoodLiars But remember, folks: It’s the libtards who are the sheep!
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46442
# RT @ResetVI: Russell Wilson has a better deep ball than Patrick Mahomes and it’s not close sadly
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46443
# RT @shybymoonlight: HOT DEMON B!TCHES NEAR U ! ! ! https://t.co/iqAWvuDAuL
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46444
# @TheEricGoldman Had no idea the Adult Swim Infomercials team were partnering with UK TV stations
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46445
# I did not read it in the order I think it was meant to be read 😂
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46446
# You are in denial mode. You are scared of The Warriors 9. Max Payne 1 4366 announcement is coming. YOU'LL SEE then you will start covering news all of a sudden.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46447
# WAIT HELP I THOUGHT SEX HAVERS WAS KARL QUACKITY AND GEORGE 😭😭
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46448
# Limited Run Games 6 Year Anniversary Giveaway https://t.co/wRqqBHMpzg
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46449
# Customer Comes Grocery Store Buys 8 Items Write Python Program Prompts User Name Item Pric Q30645314 https://t.co/GNMO9ANFKu #order #customessays
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46450
# same barry
# #trainerlucas #trainerdawn #trainerbarry #pokemonplatinum #clingyshipping #twinleafshipping #fortuneshipping #artistsontwitter https://t.co/WhZnNSWfYW
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  46451
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ef209f235885> in <module>
#       2 twitter_stream = Stream(auth, listener=TweetsListener())
#       3
# ----> 4 twitter_stream.sample(languages =["en"])
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in sample(self, is_async, languages, stall_warnings)
#     447         if stall_warnings:
#     448             self.session.params['stall_warnings'] = 'true'
# --> 449         self._start(is_async)
#     450
#     451     def filter(self, follow=None, track=None, is_async=False, locations=None,
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
