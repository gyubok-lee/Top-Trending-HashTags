# %%
# Twitter Streaming API
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream, StreamListener

# API Key & Token Info
import const

# Kafka
from kafka import KafkaProducer
from kafka import KafkaConsumer
from kafka.errors import KafkaError

import json

# %%
class Producer():
    def __init__(self, bootstrap_servers):
        try:
            self.producer = KafkaProducer(bootstrap_servers=bootstrap_servers,
                                          max_block_ms = 10000,
                                          retries = 0, 
                                          acks = 1, 
                                          value_serializer = lambda v: json.dumps(v).encode("utf-8"))
        except KafkaError as exc:
            print(f"kafka producer - Exception during connecting to broker - {exc}")
            return False
    
    def stop(self):
        self.producer.close()

    def send_data(self, topic, data):        
        # Asynchronous by default
        self.producer.send(topic, data).add_callback(self.on_send_success).add_errback(self.on_send_error)
        
        # block until all async messages are sent
        self.producer.flush()
    
    def on_send_success(self, record_metadata):
        print("**********Send Success***********")
        print("record_metadata.topic: ", record_metadata.topic)
        print("record_metadata.partition: ", record_metadata.partition)
        print("record_metadata.offset: ", record_metadata.offset)
        pass

    def on_send_error(self, excp):
        print("**********Send Error Occur**********")
        log.error("I am an errback", exc_info=excp)

# %%
# Read the credentials form const
CONSUMER_KEY = const.CONSUMER_KEY
CONSUMER_SECRET = const.CONSUMER_SECRET
ACCESS_TOKEN = const.ACCESS_TOKEN
ACCESS_SECRET = const.ACCESS_SECRET

# %%
class TweetsListener(StreamListener):
    def __init__(self):
        super(TweetsListener, self).__init__()
        self.producer = kafka_producer
        self.topic_name = topic_name
        
    def on_data(self, data):
        try:
            msg = json.loads(data)
            
            if not msg['truncated']:
                text = msg['text']
            else:
                text = msg['extended_tweet']['full_text']

            print(text)
            
            #text = text.encode('utf-8')
            self.producer.send_data(self.topic_name, text)

        except BaseException as e:
            print(f"error: {str(e)}")

        return True
    
    def on_error(self, status):
        print(status)
        
        return True

# %%
# Create Kafka Producer 
bootstrap_servers = ['localhost:9092'] # kafka broker ip
topic_name = 'tweets' # kafka topic name
kafka_producer = Producer(bootstrap_servers=bootstrap_servers)

 #Create Auth object
auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# %%
# Send tweets to Kafka Broker
twitter_stream = Stream(auth, listener=TweetsListener())

twitter_stream.sample(languages =["en"])
# Out:
# RT @GAM3SVT: also, we are aiming a lot higher than music show wins. they are important to us, but we are also aiming for breaking long-time…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43775
# RT @sparkling_Sona: he is a fighter and he has never learnt to give up &lt;3 he's ready to push himself to any extent that's required to reach…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43776
# @theREALTatBea @sabrinaGuwop Brackin
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43777
# RT @charliekirk11: Let’s Go Brandon
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43778
# @chixierae @charlidamelio ur so talented
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43779
# RT @incessyaoi: Meant to be. ♥️💚 https://t.co/DE68KaOo6b
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43780
# @palletjkk min yoongi
# I vote #TheMusicVideo #BUTTER at the #PCAs 2021 @BTS_twt
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43781
# RT @Diablo_Santana: @SashaBradashaw To infinity &amp; beyond
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43782
# Exactly… smh
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43783
# I have a confession. I hardcast Adloquim even when I definitely have aether charges, because the big yellow shield makes the brain feel good.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43784
# me too
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43785
# RT @Wired4Music: SHARE THIS WITH YOUNG MUSICIANS
#
# We’re doing a one-off Wired4Music Drop-in on 17 November from 5pm-8pm in the Sound Conne…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43786
# @Chicago_Scanner And to think it was Halloween!
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43787
# @danielle_renes Nope
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43788
# @binance $oht 0xf9f546af036d3166b59027ec15892d0cde808fd8
#
# Just 10k tokens have buy some from this it will pump hard
#
# https://t.co/561zNV7FlP
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43789
# RT @anonymous1gi: LOUDER.I  so agree to this as a doc. I tell patients also we love  helping u but dont put us on pedestal , bring so many…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43790
# RT @AwaLuneArt: I’m kinda bored..sooooo
#
# 🌟🌟!!!!ART SHARE!!!!🌟🌟
# 🌟🌟!!!!ART SHARE!!!!🌟🌟
# 🌟🌟!!!!ART SHARE!!!!🌟🌟
#
# -comment your amazing arts wit…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43791
# RT @EROCK_Eagles: Von Miller gets traded for 2 second day picks…we’ll be lucky to get an expired Wawa coupon for Barnett.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43792
# RT @marcan42: Say hi to Linux on the M1 Pro
#
# (okay, it doesn't quite boot all the way yet, but it's almost there!) https://t.co/mRF697AB29
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43793
# @bigratkiller @Isonomist We will still be here and on YouTube...
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43794
# RT @FtK_Artist: One more Costumed Rivet ^__^ This time as Poison Ivy, with a more organic prosthesis ^_^ https://t.co/QkyunUwXhQ
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43795
# @TaistoFCB @Vav4ta @jxsprr Doubt
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43796
# RT @haileysoutfits: '... than a different one at different times of life. At a different time in life words were really important too, and…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43797
# RT @AitaiKuji: #YuYuHakusho is coming with a variety of goods featuring Yusuke, Kazuma, Kurama, Hiei, and Youko Kurama in tuxedos! Items in…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43798
# RT @IgnaciaElla: You have nice hands, I want You to finger me
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43799
# @faithfltr @BTS_twt you are beautiful
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43800
# RT @eroticvideos_: Part 3 https://t.co/hEIOmI4SJL
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43801
# RT @ramseyboltin: That elevated court was taking souls💀 https://t.co/AkDJSqhZFb
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43802
# RT @SafeMoonInu: 🚨SMI will soon enable Fiat-to-Crypto service 💳➡️🐶🎮🚀
#
# SMI enthusiasts will soon be able to conveniently use fiat to purchas…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43803
# RT @alex_abads: into every generation, a slayer is born: https://t.co/RtIg2c1Ocy
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43804
# @azaryajason4 How old do you think I am lmao
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43805
# RT @jhaaa_loeyyy: hmmmmm 🤔🤭
#
#                    🕯        🕯
#           🕯                            🕯
#             “someone ordered
#     🕯  you…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43806
# RT @_ashishsinghdr: Every lie you tell incurs a debt to the truth. Sooner or later that debt has to be paid.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43807
# RT @babybadassNFT: 🎁Another Giveaway-courtesy our very own, SHILL SHADY!🎁
#
# Mints #3471-#3521 will all draw for 8 free NFTs, donated by him!…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43808
# @schollsbeav @JWAshley404 @thehill @JayInslee And super duper pooper raw sewage…and needles…
#
# Thanks @GovInslee
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43809
# @aegean2356 hi friends, trust me you'll love this one 🔥🌈
#
# https://t.co/2lxsfD0wS9
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43810
# RT @DonaldBKipkorir: When uda leadership is in Mount Kenya Region, they run a sly bigoted narrative against Luo Nation. In ODM stronghold o…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43811
# RT @loveis9597: His cute face and hair and hot piercings 🥺 https://t.co/2sNkwiaMcu
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43812
# RT @HanakunCart: #HNKCartGo | PH GO / WTS / LFB
#
# SM Artists Seasons Greetings 2022 Reservations
#
# Girls Generation Oh!GG
# Super Junior
# TVXQ
# S…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43813
# // head in hands..,.,, she tries so hard
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43814
# @JoeBiden Paper thin. Onion paper.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43815
# @itsFreddieEpp Yeah ighttttt 😭😭😭 ima fck with it
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43816
# RT @ArtController1: Welp....it's finally done, all 31 days of my life spent making that amount if not, more, of art works from different ar…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43817
# @EnohoEmeje Pinnick at work with his puppet coach
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43818
# @SerkanArikan06 Scammers using the same pictures on different accounts https://t.co/mRk1pC6sUa
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43819
# RT @adgpi: 'सदा सतर्क'
#
# General MM Naravane #COAS and All Ranks of #IndianArmy convey best wishes to All Ranks, Veterans and families of In…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43820
# @Schadenfury Everything I put on TV makes me greet. enough 🤣
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43821
# @lindarchilders Puckerface must be a maestro with that tongue.😳
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43822
# RT @xclaudius: me: shit isn’t due till november i got time
#
# november: https://t.co/WijuTeXmOx
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43823
# RT @jaemcityx: GIVEAWAY $150 | 2.000.000 IDR
#
# - retweet
# - follow @SuperBuddha__ &amp; @UswapNFT
# end 12 hours.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43824
# @OMG_its_Jo_ Just don’t hit that bump smh
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43825
# @lapisren ahhh ty ren TT &lt;3
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43826
# RT @princesspromos_: $80 | 1.120.000 IDR || 10 HOURS
#
# • RT &amp; Follow @synapse_reality
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43827
# RT @AdamSchefter: As part of the trade, the Broncos are paying $9 million of Von Miller’s remaining $9.7 million salary, per sources.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43828
# Chief Keef - Ten Toes Down (Prod by DPGGP) (DatPiff Exclusive) (Sorry 4 The Weight)
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43829
# @ndumnyandu I felt violated 😭😭😭😭😭😭
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43830
# @Jeffreeder666 i just want to let you know, someones using your profile picture to scam people through snapchat.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43831
# RT @Coventry_City: NEWS: Take a look at the Matchday Guide for Tuesday night's clash vs Swansea City at the Coventry Building Society Arena…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43832
# RT @PaulHembo: World Series end time (eastern):
#
# Game 5 (12:15)
# Game 4 (11:54)
# Game 3 (11:33)
# Game 2 (11:20)
# Game 1 (12:15)
#
# Each of the la…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43833
# @Glastomichelle Great photo and zombie walk was fun
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43834
# I vote for #Juliette for #InfluencerBrasil of 2021 #PCAs
#
# quatorze
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43835
# RT @rdrhwke: To all the wokies crying about the pilot saying, "Lets Go Brandon." You were ok with DiNiro saying "Fook Trump", ok with Kathy…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43836
# RT @bop_tc: It has been 273 days today since our lovely kind gentle loving Fozzy unexpectedly gained his wings. We miss him so much. But kn…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43837
# RT @disclosetv: NEW - New York City: 9,000 city workers on "unpaid leave" and 12,000 requested exemptions as vaccine mandate takes effect.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43838
# RT @GazetteNGR: Fulanis are outnumbering Kwara indigenes, Gov. AbdulRazaq cries out https://t.co/Fjw3QUKYxh
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43839
# @JCRev4 *scoff* like being a sinner scares me 🙄🙄🙄
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43840
# RT @EricDJuly: You are a punk bitch
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43841
# ⛏️ More iron ore than you can shake a stick at!
#
# 🚜 Iron ore Farming Route. New World.
#
# 🔥 https://t.co/yIjPOHxirs 🔥
#
# ✅ Make sure to like comment, share, subscribe, if you would like to support me as a creator. ✅
#
# @playnewworld #NewWorldMMO #NewWorldMMORPG #PlayNewWorld https://t.co/OeArKvMeMl
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  

# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43868
# RT @chillustrates: I got posca markers finally.. and I drew my child :3 https://t.co/J6HGrRoEnq
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43869
# @Ntandz It's only difficult if you feel conflicted. For us EFF voters it's a walk in the park
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43870
# @hakyeons_star HE LOOKS LIKE A FAIRY OMGG
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43871
# RT @amywestervelt: Literally no one is afraid COP will be too aggressive
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43872
# @Apoorvaxo imtentional https://t.co/uHbFWMokA2
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43873
# @j1mmyza hope you feel better tomorrow, Miller, hugging you very tightly. you dont deserve these struggles and this pain, i wish they just passed you by, its so shit. you're so strong though, you're wonderful. I'll get better, so definitely will 💜 https://t.co/w6WJdSNjka
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43874
# this is an example tweet
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43875
# will you tell the truth so i don't have to lie?
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43876
# RT @fxhunty: The fathers face 😭 https://t.co/CmNXSqDmLJ
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43877
# RT @btschartdata: 'Butter' has surpassed 600 million views on Youtube, their 11th MV to achieve this! https://t.co/7aXMtZR3pi
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43878
# RT @GFuelEnergy: 🍬 𝐆𝐈𝐕𝐄𝐀𝐖𝐀𝐘 + 𝐁𝐎𝐆𝐎 𝐒𝐀𝐋𝐄 👻
#
# 🗣️ YO! Halloween may be over, but guess what?? BUY 1 #GFUEL TUB, GET 1 TUB FREE on our CANDY-ins…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43879
# RT @_Pammy_DS_: Unhealed trauma will have you mistaking healthy relationships as boring and unexciting because you're so used to the chaos…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43880
# This guy @HWMitnick is a scammer be careful
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43881
# RT @GoI_MeitY: What are the new #ITRules2021?
#
# Read the document released by MoS @Rajeev_GoI today that attempts to respond to general quer…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43882
# @spookyhaley_ Yay Happy spooky Pup is home and adorable
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43883
# @Shibtoken Hey! Have you heard of @CryptoHippies0? ☮️ The wildest Play2Earn game is coming to the Binance Smart Chain! Collect &amp; Evolve Hippies, Grow ☘️ Weed, Sell 🍄 Trips, Trade 🖼 NFTs, and earn $Hippie! 🔐Contract audited with @SolidProof_io
# TG: https://t.co/V5hPuilk1P  #CryptoHippies
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43884
# @tbu_d3athlok @aquaa @mitr0 @BoopNL_ @Mongraal @X8Creator they are still friends btw mature people forgive eachother also mongraal was hyping aqua up yesterday in the grand finals in motors stream
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43885
# @ProjectSupremee Can I pls have rubux
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43886
# @cookierunpride And that’s not a bad thing at all. There’s nothing incorrect about the fact that lesbian as a word has evolved differently than the word gay. Its very clear how distinct they are from eachother. There is nothing gained from trying to use a word in its past context
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43887
# RT @kpopggontop: Most Streamed Female Groups in 2021 so far:
#
# Spotify
# 1. BLACKPINK
# 2. Little Mix
# 3. Twice
# 4. Itzy
#
# YouTube
# 1. BLACKPINK
# 2.…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43888
# RT @AdamTaylorXXX: @LeoRazxx @carlitos17bcn Dm me 😈 https://t.co/aRX0huZfC6
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43889
# RT @Nicolette_Shea: I thought you was an angel https://t.co/89K0kmIzKZ https://t.co/5dyMUww5gm
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43890
# RT @awakenindiamvmt: Despite these numbers, the CDC and the FDA still approved the booster dose for this age group.
#
# COVID-19 cases and hos…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43891
# @ImVontee Depends on the person but they gotta be driving a hour to see me too
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  43892
# RT @sarajcox: 9 days to goooooo til we get Between The Covers for the third series @BBCTwo next weds 10th nov 7.30pm 👏🏼👏🏼👏🏼we feature 6 bra…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45540
# @StuartFeiner Stu, permission to start a go fund me to keep the pool running at 88 throughout the winter?
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45541
# RT @chrryskies: no this is illegal https://t.co/IDOCaiX4hX
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45542
# RT @DebraErnst14: @RogueCitizenOne @TerryMcAuliffe Keep Virginia Blue! A vote for Terry is a vote against Trump…
# You don’t want another Cha…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45543
# Fighting the good fight. Well done! 👮‍♂️👮🏾💪🏽 #StandStrong #HoldTheLine
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45544
# Instead of being Envy, This type of Support is Expected from Every Nationalists when Our Fellow Member is leading the Cause from the Front without caring for her life.
#
# Hat's off for @kajal_jaihind ji.
# 👏🏻👏🏻👏🏻 https://t.co/b3l9hqGVth
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45545
# couple goals #ARMYSelcaDay #ARSD https://t.co/C3ITb1k6ol
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45546
# I am going to be here 🥺💖 https://t.co/GtBc90YkuV
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45547
# @thebeesyss @pmpkinptchs GOSH -nick
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45548
# RT @susruby: $20┆920 PHP┆280.000 IDR
#
# - retweet
# - rt/like @edz_lozano 📌
#
# end 2 hours.
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45549
# RT @dreamonastring: dream and sapnap in their various costumes https://t.co/ah7pzC4rGq
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45550
# [ SNEEZE ]
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45551
# me and my bestie always make plans but then unilaterally cancel it cuz we know the other aint up for that either
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45552
# RT @ItsZaeOk: WHY I JUST SAW MARIAH CAREY WITH REINDEER FLYING OUTSIDE MY HOUSE?!?!?!?
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45553
# @iLTHOBI91 faitin lucy
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45554
# RT @IanCockerill2: The rank hypocrisy of this Con26 event is truly breathtaking. The do as I say and not as I do brigade are on another cru…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45555
# RT @nqobile_mahungu: This is broke my heart 💔💔😩 https://t.co/j5gPpn3N20
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45556
# RT @iamMarcElliott: Pizza delivery for robbery homicide https://t.co/BWsrZRwoQN
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45557
# RT @scope: 🎮 Our gaming fundraiser #PowerUpAndPlay was co-produced with 7 disabled gamers.
#
# @ThinesG
# @lysander_hugo
# @sightlesskombat
# @chri…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45558
# RT @News24: WATCH LIVE | DA Federal Council Chairperson Helen Zille has opened a case of assault against a police officer, after she was se…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45559
# @LOUISKIWI28 i think that only for you i have a certain answer, i find milo very intelligent and dedicated like he has the one who decided to search for atlantis and i dont know i see you reflected in him a lot, like i find you very very intelligent but also dedicated of what u are+
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45560
# RT @EARTH199999MCU: New still from #NoWayHome ? https://t.co/jT7DeNbQkg
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45561
# @unhealthytruth Who am I disparaging in this tweet? Just scroll the feed. The comment I responded too claim it's all shut up and don't speak for 8hr a day, yeah it's real quiet in gym, group projects, recess, lunch, in between. See how your still making up bullshit?🧐
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45562
# @FiresideYankees TRADE
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45563
# RT @endclasssociety: Prostitution makes sense when you understand it as violence arising from a class society that made women its first for…
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45564
# Still so good https://t.co/br1gz7SlG3
# **********Send Success***********
# record_metadata.topic:  tweets
# record_metadata.partition:  0
# record_metadata.offset:  45565
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-ef209f235885> in <module>
#       2 twitter_stream = Stream(auth, listener=TweetsListener())
#       3
# ----> 4 twitter_stream.sample(languages =["en"])
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in sample(self, is_async, languages, stall_warnings)
#     447         if stall_warnings:
#     448             self.session.params['stall_warnings'] = 'true'
# --> 449         self._start(is_async)
#     450
#     451     def filter(self, follow=None, track=None, is_async=False, locations=None,
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\http\client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\samsung\appdata\local\programs\python\python37\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
